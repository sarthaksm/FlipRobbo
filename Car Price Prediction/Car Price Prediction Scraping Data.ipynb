# %% [markdown]
# # Car Price Prediction
# ##  Importing Libraries

# %%
import pandas as pd
import selenium
from selenium import webdriver
from selenium.webdriver.common.by import By
from selenium.webdriver.support.ui import WebDriverWait
from selenium.common.exceptions import NoSuchElementException
import time

import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# # 1. Scraping data from "Cardekho" Website
# ### Ahmedabad

# %%
driver1=webdriver.Chrome(r"C:\Users\hp pc\Downloads\chromedriver_win32 (1)\chromedriver.exe")
url1=("https://www.cardekho.com/used-cars")
driver1.get(url1)
driver1.maximize_window()
time.sleep(2)

# %%
location_Ahmedabad= driver1.find_element(By.XPATH,"//a[@title='Used cars in Ahmedabad']").click()

# %%
# scrolling the web page 
for _ in range(300):
    driver1.execute_script("window.scrollBy(0,100)")

# %%
urls = []
for i in range(20):
    for j in driver1.find_elements(By.XPATH,'//div[@class="gsc_col-xs-7  carsName"]/a'):
        urls.append(j.get_attribute('href'))

time.sleep(2)
print(len(urls))
# Out:
# 0

# %%
#Creating empty list 
Brand= []
Model = []
Variant=[]
Manufacturing_Year = []
Driven_KiloMeters= []
Fuel = []
Location= []
Car_Price= []

#Fetching data for Brand    
try:
    Brand_name=driver1.find_elements(By.XPATH,"//div[@class='gsc_col-xs-7  carsName']/a")
    for i in Brand_name:
        Brand.append(i.text.split(" ")[1])
except NoSuchElementException as e:
    Brand.append('-')

#Fetching data for Model   
try:
    Model_name=driver1.find_elements(By.XPATH,"//div[@class='gsc_col-xs-7  carsName']/a")
    for i in Model_name:
        Model.append(i.text[5:])
except NoSuchElementException as e:
    Model.append('-')

#Fetching data for Variant   
try:
    Variant_name=driver1.find_elements(By.XPATH,"//div[@class='car_variant']")
    for i in Variant_name:
        Variant.append(i.text)
except NoSuchElementException as e:
    Variant.append('-')

#Fetching data for Manufacturing    
try:
    Manufacturing=driver1.find_elements(By.XPATH,"//div[@class='gsc_col-xs-7  carsName']/a")
    for i in Manufacturing:
        Manufacturing_Year.append(i.text.split(" ")[0])
except NoSuchElementException as e:
    Manufacturing_Year.append('-') 

#Fetching data for Driven_KiloMeters    
try:
    Driven_KiloMeter=driver1.find_elements(By.XPATH,'//div[@class="truncate dotlist-2"]/div[1]')
    for i in Driven_KiloMeter:
        Driven_KiloMeters.append(i.text)
except NoSuchElementException as e:
    Driven_KiloMeters.append('-')    

#Fetching data for Fuel    
try:
    Fuel_name=driver1.find_elements(By.XPATH,'//div[@class="truncate dotlist-2"]/div[2]')
    for i in Fuel_name:
        Fuel.append(i.text)
except NoSuchElementException as e:
    Fuel.append('-')

#Fetching data for Location   
try:
    Location_name=driver1.find_elements(By.XPATH,'//div[@class="gsc_col-xs-12 mainheading"]')
    for j in range (200):
        for i in Location_name:
            Location.append(i.text[13:])
except NoSuchElementException as e:
    Location.append('-')

#Fetching data for Car_Price    
try:
    Car_Pr=driver1.find_elements(By.XPATH,"//span[@class='amnt ']")
    for i in Car_Pr:
        Car_Price.append(i.text)
except NoSuchElementException as e:
    Car_Price.append('-')

# %%
print(len(Brand),len(Model),len(Variant),len(Manufacturing_Year), len(Driven_KiloMeters), len(Fuel),  len(Location), len(Car_Price))
# Out:
# 0 0 0 0 0 0 0 0

# %%
Ahmedabad=pd.DataFrame({'Brand':Brand[:20], 'Model':Model[:20], 'Variant':Variant[:20], 'Manufacturing_Year':Manufacturing_Year[:20], 'Driven_KiloMeters':Driven_KiloMeters[:20], 'Fuel':Fuel[:20],  'Location':Location[:20], 'Car_Price':Car_Price[:20]})
Ahmedabad
# Out:
# Empty DataFrame
# Columns: [Brand, Model, Variant, Manufacturing_Year, Driven_KiloMeters, Fuel, Location, Car_Price]
# Index: []

# %%
driver1.close()

# %% [markdown]
# ## Bangalore

# %%
driver2=webdriver.Chrome(r"C:\Users\hp pc\Downloads\chromedriver_win32 (1)\chromedriver.exe")
url2=("https://www.cardekho.com/used-cars")
driver2.get(url2)
driver2.maximize_window()
time.sleep(2)

# %%
#fetching location
location_Bangalore= driver2.find_element(By.XPATH,"//a[@title='Used cars in Bangalore']").click()

# %%
# scrolling the web page
for _ in range(30):
    driver2.execute_script("window.scrollBy(0,1000)")

# %%
urls2 = []
for i in range(30):
    for j in driver2.find_elements(By.XPATH,'//div[@class="gsc_col-xs-7  carsName"]/a'):
        
        urls2.append(j.get_attribute('href'))

time.sleep(2)

print(len(urls2))
# Out:
# 0

# %%
#Creating empty list 
Brand2 = []
Model2 = []
Variant2 = []
Manufacturing_Year2 = []
Driven_KiloMeters2 = []
Fuel2 = []
Location2 = []
Car_Price2 = []


#Fetching data for Brand    
try:
    Brand_name2=driver2.find_elements(By.XPATH,"//div[@class='gsc_col-xs-7  carsName']/a")
    for i in Brand_name2:
        Brand2.append(i.text.split(" ")[1])
except NoSuchElementException as e:
    Brand2.append('-')
    
#Fetching data for Model   
try:
    Model_name2=driver2.find_elements(By.XPATH,"//div[@class='gsc_col-xs-7  carsName']/a")
    for i in Model_name2:
        Model2.append(i.text[5:])
except NoSuchElementException as e:
    Model2.append('-')

#Fetching data for Variant   
try:
    Variant_name2=driver2.find_elements(By.XPATH,"//div[@class='car_variant']")
    for i in Variant_name2:
        Variant2.append(i.text)
except NoSuchElementException as e:
    Variant2.append('-')
    
#Fetching data for Manufacturing    
try:
    Manufacturing2=driver2.find_elements(By.XPATH,"//div[@class='gsc_col-xs-7  carsName']/a")
    for i in Manufacturing2:
        Manufacturing_Year2.append(i.text.split(" ")[0])
except NoSuchElementException as e:
    Manufacturing_Year2.append('-') #Creating empty list 
Brand2 = []
Model2 = []
Variant2 = []
Manufacturing_Year2 = []
Driven_KiloMeters2 = []
Fuel2 = []
Location2 = []
Car_Price2 = []


#Fetching data for Brand    
try:
    Brand_name2=driver2.find_elements(By.XPATH,"//div[@class='gsc_col-xs-7  carsName']/a")
    for i in Brand_name2:
        Brand2.append(i.text.split(" ")[1])
except NoSuchElementException as e:
    Brand2.append('-')
    
#Fetching data for Model   
try:
    Model_name2=driver2.find_elements(By.XPATH,"//div[@class='gsc_col-xs-7  carsName']/a")
    for i in Model_name2:
        Model2.append(i.text[5:])
except NoSuchElementException as e:
    Model2.append('-')

#Fetching data for Variant   
try:
    Variant_name2=driver2.find_elements(By.XPATH,"//div[@class='car_variant']")
    for i in Variant_name2:
        Variant2.append(i.text)
except NoSuchElementException as e:
    Variant2.append('-')
    
#Fetching data for Manufacturing    
try:
    Manufacturing2=driver2.find_elements(By.XPATH,"//div[@class='gsc_col-xs-7  carsName']/a")
    for i in Manufacturing2:
        Manufacturing_Year2.append(i.text.split(" ")[0])
except NoSuchElementException as e:
    Manufacturing_Year2.append('-') 
    
#Fetching data for Driven_KiloMeters    
try:
    Driven_KiloMeter2=driver2.find_elements(By.XPATH,'//div[@class="truncate dotlist-2"]/div[1]')
    for i in Driven_KiloMeter2:
        Driven_KiloMeters2.append(i.text)
except NoSuchElementException as e:
    Driven_KiloMeters2.append('-')    

#Fetching data for Fuel    
try:
    Fuel_name2=driver2.find_elements(By.XPATH,'//div[@class="truncate dotlist-2"]/div[2]')
    for i in Fuel_name2:
        Fuel2.append(i.text)
except NoSuchElementException as e:
    Fuel2.append('-')

#Fetching data for Location       
try:
    Location_name2=driver2.find_elements(By.XPATH,'//div[@class="gsc_col-xs-12 mainheading"]')
    for j in range (200):
        for i in Location_name2:
            Location2.append(i.text[13:])
except NoSuchElementException as e:
    Location2.append('-')
    
#Fetching data for Car_Price    
try:
    Car_Pr2=driver2.find_elements(By.XPATH,"//span[@class='amnt ']")
    for i in Car_Pr2:
        Car_Price2.append(i.text)
except NoSuchElementException as e:
    Car_Price2.append('-')

# %%
print(len(Brand2),len(Model2),len(Variant2),len(Manufacturing_Year2), len(Driven_KiloMeters2), len(Fuel2),  len(Location2), len(Car_Price2))
# Out:
# 0 0 0 0 0 0 0 0

# %%
Bangalore=pd.DataFrame({'Brand':Brand2[:20], 'Model':Model2[:20], 'Variant':Variant2[:20], 'Manufacturing_Year':Manufacturing_Year2[:100], 'Driven_KiloMeters':Driven_KiloMeters2[:20], 'Fuel':Fuel2[:20], 'Location':Location2[:20], 'Car_Price':Car_Price2[:20]})
Bangalore
# Out:
# Empty DataFrame
# Columns: [Brand, Model, Variant, Manufacturing_Year, Driven_KiloMeters, Fuel, Location, Car_Price]
# Index: []

# %%
driver2.close()

# %% [markdown]
# ## Delhi NCR

# %%
driver3=webdriver.Chrome(r"C:\Users\hp pc\Downloads\chromedriver_win32 (1)\chromedriver.exe")
url2=("https://www.cardekho.com/used-cars")
driver3.get(url2)
driver3.maximize_window()
time.sleep(2)

# %%
location_Delhi= driver3.find_element(By.XPATH,"//a[@title='Used cars in Delhi NCR']").click()

# %%
# scrolling the web page to get more images
for _ in range(100):
    driver3.execute_script("window.scrollBy(0,100)")

# %%
urls3 = []
for i in range(10):
    for j in driver3.find_elements(By.XPATH,'//div[@class="gsc_col-xs-7  carsName"]/a'):
        urls3.append(j.get_attribute('href'))

time.sleep(2)
print(len(urls3))
# Out:
# 200

# %%
#Creating empty list 
Brand3= []
Model3 = []
Variant3=[]
Manufacturing_Year3 = []
Driven_KiloMeters3= []
Fuel3 = []
Location3= []
Car_Price3= []

#Fetching data for Brand    
try:
    Brand_name3=driver3.find_elements(By.XPATH,"//div[@class='gsc_col-xs-7  carsName']/a")
    for i in Brand_name3:
        Brand3.append(i.text.split(" ")[1])
except NoSuchElementException as e:
    Brand3.append('-')
    
#Fetching data for Model   
try:
    Model_name3=driver3.find_elements(By.XPATH,"//div[@class='gsc_col-xs-7  carsName']/a")
    for i in Model_name3:
        Model3.append(i.text[5:])
except NoSuchElementException as e:
    Model3.append('-')

#Fetching data for Variant   
try:
    Variant_name3=driver3.find_elements(By.XPATH,"//div[@class='car_variant']")
    for i in Variant_name3:
        Variant3.append(i.text)
except NoSuchElementException as e:
    Variant3.append('-')
    
#Fetching data for Manufacturing    
try:
    Manufacturing3=driver3.find_elements(By.XPATH,"//div[@class='gsc_col-xs-7  carsName']/a")
    for i in Manufacturing3:
        Manufacturing_Year3.append(i.text.split(" ")[0])
except NoSuchElementException as e:
    Manufacturing_Year3.append('-') 
    
#Fetching data for Driven_KiloMeters    
try:
    Driven_KiloMeter3=driver3.find_elements(By.XPATH,'//div[@class="truncate dotlist-2"]/div[1]')
    for i in Driven_KiloMeter3:
        Driven_KiloMeters3.append(i.text)
except NoSuchElementException as e:
    Driven_KiloMeters3.append('-')    

#Fetching data for Fuel    
try:
    Fuel_name3=driver3.find_elements(By.XPATH,'//div[@class="truncate dotlist-2"]/div[2]')
    for i in Fuel_name3:
        Fuel3.append(i.text)
except NoSuchElementException as e:
    Fuel3.append('-')
    
#Fetching data for Car_Price    
try:
    Car_Pr3=driver3.find_elements(By.XPATH,"//span[@class='amnt ']")
    for i in Car_Pr3:
        Car_Price3.append(i.text)
except NoSuchElementException as e:
    Car_Price3.append('-')

# %%
print(len(Brand3),len(Model3),len(Variant3),len(Manufacturing_Year3), len(Driven_KiloMeters3), len(Fuel3),  len(Car_Price3))
# Out:
# 20 20 20 20 20 20 20

# %%
#Fetching data for Location       
try:
    Location_name3=driver3.find_elements(By.XPATH,'//div[@class="gsc_col-xs-12 mainheading"]')
    for j in range (380):
        for i in Location_name3:
            Location3.append(i.text[13:])
except NoSuchElementException as e:
    Location3.append('-')

# %%
len(Location3)
# Out:
# 380

# %%
Delhi=pd.DataFrame({'Brand':Brand3[:380], 'Model':Model3[:380], 'Variant':Variant3[:380], 'Manufacturing_Year':Manufacturing_Year3[:380], 'Driven_KiloMeters':Driven_KiloMeters3[:380], 'Fuel':Fuel3[:380],  'Car_Price':Car_Price3[:380]})
Delhi
# Out:
#        Brand              Model                                     Variant  \
# 0     Maruti      Maruti Baleno                                   1.2 Delta
# 1     Maruti        Maruti Ciaz                                  Delta BSIV
# 2    Hyundai      Hyundai Venue                      SX Plus Turbo DCT BSIV
# 3     Maruti     Maruti Celerio                       VXI CNG Optional BSIV
# 4     Maruti      Maruti Baleno                                   1.2 Delta
# 5    Hyundai      Hyundai Creta                                 1.6 CRDi SX
# 6     Maruti        Maruti Ciaz                                      AT ZXi
# 7     Maruti      Maruti Baleno                                   1.2 Delta
# 8    Hyundai        Hyundai i20                                    1.2 Asta
# 9     Toyota  Toyota Etios Liva                                       1.2 G
# 10  Mahindra      Mahindra Thar                                        CRDe
# ...

# %%
driver3.close()

# %% [markdown]
# ## Mumbai

# %%
driver4=webdriver.Chrome(r"C:\Users\hp pc\Downloads\chromedriver_win32 (1)\chromedriver.exe")
url4=("https://www.cardekho.com/used-cars")
driver4.get(url4)
driver4.maximize_window()
time.sleep(2)

# %%
location_Mumbai= driver4.find_element(By.XPATH,"//a[@title='Used cars in Mumbai']").click()

# %%
# scrolling the web page to get more images
for _ in range(500):
    driver4.execute_script("window.scrollBy(0,100)")

# %%
urls4 = []
for i in range(10):
    for j in driver4.find_elements(By.XPATH,'//div[@class="gsc_col-xs-7  carsName"]/a'):
        
        urls4.append(j.get_attribute('href'))

time.sleep(2)
print(len(urls4))
# Out:
# 0

# %%
#Creating empty list 
Brand4= []
Model4 = []
Variant4=[]
Manufacturing_Year4 = []
Driven_KiloMeters4= []
Fuel4 = []
Location4= []
Car_Price4= []


#Fetching data for Brand    
try:
    Brand_name4=driver4.find_elements(By.XPATH,"//div[@class='gsc_col-xs-7  carsName']/a")
    for i in Brand_name4:
        Brand4.append(i.text.split(" ")[1])
except NoSuchElementException as e:
    Brand4.append('-')
    
#Fetching data for Model   
try:
    Model_name4=driver4.find_elements(By.XPATH,"//div[@class='gsc_col-xs-7  carsName']/a")
    for i in Model_name4:
        Model4.append(i.text[5:])
except NoSuchElementException as e:
    Model4.append('-')

#Fetching data for Variant   
try:
    Variant_name4=driver4.find_elements(By.XPATH,"//div[@class='car_variant']")
    for i in Variant_name4:
        Variant4.append(i.text)
except NoSuchElementException as e:
    Variant4.append('-')
    
#Fetching data for Manufacturing    
try:
    Manufacturing4=driver4.find_elements(By.XPATH,"//div[@class='gsc_col-xs-7  carsName']/a")
    for i in Manufacturing4:
        Manufacturing_Year4.append(i.text.split(" ")[0])
except NoSuchElementException as e:
    Manufacturing_Year4.append('-') 
    
#Fetching data for Driven_KiloMeters    
try:
    Driven_KiloMeter4=driver4.find_elements(By.XPATH,'//div[@class="truncate dotlist-2"]/div[1]')
    for i in Driven_KiloMeter4:
        Driven_KiloMeters4.append(i.text)
except NoSuchElementException as e:
    Driven_KiloMeters4.append('-')    

#Fetching data for Fuel    
try:
    Fuel_name4=driver4.find_elements(By.XPATH,'//div[@class="truncate dotlist-2"]/div[2]')
    for i in Fuel_name4:
        Fuel4.append(i.text)
except NoSuchElementException as e:
    Fuel4.append('-')
    
#Fetching data for Car_Price    
try:
    Car_Pr4=driver4.find_elements(By.XPATH,"//span[@class='amnt ']")
    for i in Car_Pr4:
        Car_Price4.append(i.text)
except NoSuchElementException as e:
    Car_Price4.append('-')

# %%
print(len(Brand4),len(Model4),len(Variant4),len(Manufacturing_Year4), len(Driven_KiloMeters4), len(Fuel4), len(Car_Price4))
# Out:
# 0 0 0 0 0 0 0

# %%
#Fetching data for Location       
try:
    Location_name4=driver4.find_elements(By.XPATH,'//div[@class="gsc_col-xs-12 mainheading"]')
    for j in range (200):
        for i in Location_name4:
            Location4.append(i.text[13:])
except NoSuchElementException as e:
    Location4.append('-')

# %%
Mumbai=pd.DataFrame({'Brand':Brand4, 'Model':Model4, 'Variant':Variant4, 'Manufacturing_Year':Manufacturing_Year4, 'Driven_KiloMeters':Driven_KiloMeters4, 'Fuel':Fuel4, 'Car_Price':Car_Price4})
Mumbai
# Out:
# Empty DataFrame
# Columns: [Brand, Model, Variant, Manufacturing_Year, Driven_KiloMeters, Fuel, Car_Price]
# Index: []

# %%
driver4.close()

# %% [markdown]
# ## Pune

# %%
driver5=webdriver.Chrome(r"C:\Users\hp pc\Downloads\chromedriver_win32 (1)\chromedriver.exe")
url5=("https://www.cardekho.com/used-cars")
driver5.get(url5)
driver5.maximize_window()
time.sleep(2)

# %%
location_Pune= driver5.find_element(By.XPATH,"//a[@title='Used cars in Pune']").click()

# %%
# scrolling the web page to get more images
for _ in range(500):
    driver5.execute_script("window.scrollBy(0,100)")

# %%
urls5 = []
for i in range(10):
    for j in driver5.find_elements(By.XPATH,'//div[@class="gsc_col-xs-7  carsName"]/a'):
        
        urls5.append(j.get_attribute('href'))

time.sleep(2)

print(len(urls5))
# Out:
# 0

# %%
#Creating empty list 
Brand5= []
Model5 = []
Variant5=[]
Manufacturing_Year5 = []
Driven_KiloMeters5= []
Fuel5 = []
Location5= []
Car_Price5= []


#Fetching data for Brand    
try:
    Brand_name5=driver5.find_elements(By.XPATH,"//div[@class='gsc_col-xs-7  carsName']/a")
    for i in Brand_name5:
        Brand5.append(i.text.split(" ")[1])
except NoSuchElementException as e:
    Brand5.append('-')
    
#Fetching data for Model   
try:
    Model_name5=driver5.find_elements(By.XPATH,"//div[@class='gsc_col-xs-7  carsName']/a")
    for i in Model_name5:
        Model5.append(i.text[5:])
except NoSuchElementException as e:
    Model5.append('-')

#Fetching data for Variant   
try:
    Variant_name5=driver5.find_elements(By.XPATH,"//div[@class='car_variant']")
    for i in Variant_name5:
        Variant5.append(i.text)
except NoSuchElementException as e:
    Variant5.append('-')
    
#Fetching data for Manufacturing    
try:
    Manufacturing5=driver5.find_elements(By.XPATH,"//div[@class='gsc_col-xs-7  carsName']/a")
    for i in Manufacturing5:
        Manufacturing_Year5.append(i.text.split(" ")[0])
except NoSuchElementException as e:
    Manufacturing_Year5.append('-') 
    
#Fetching data for Driven_KiloMeters    
try:
    Driven_KiloMeter5=driver5.find_elements(By.XPATH,'//div[@class="truncate dotlist-2"]/div[1]')
    for i in Driven_KiloMeter5:
        Driven_KiloMeters5.append(i.text)
except NoSuchElementException as e:
    Driven_KiloMeters5.append('-')    

#Fetching data for Fuel    
try:
    Fuel_name5=driver5.find_elements(By.XPATH,'//div[@class="truncate dotlist-2"]/div[2]')
    for i in Fuel_name5:
        Fuel5.append(i.text)
except NoSuchElementException as e:
    Fuel5.append('-')
    
#Fetching data for Car_Price    
try:
    Car_Pr5=driver5.find_elements(By.XPATH,"//span[@class='amnt ']")
    for i in Car_Pr5:
        Car_Price5.append(i.text)
except NoSuchElementException as e:
    Car_Price5.append('-')

# %%
print(len(Brand5),len(Model5),len(Variant5),len(Manufacturing_Year5), len(Driven_KiloMeters5), len(Fuel5), len(Car_Price5))
# Out:
# 0 0 0 0 0 0 0

# %%
#Fetching data for Location       
try:
    Location_name5=driver5.find_elements(By.XPATH,'//div[@class="gsc_col-xs-12 mainheading"]')
    for j in range (360):
        for i in Location_name5:
            Location5.append(i.text[13:])
except NoSuchElementException as e:
    Location5.append('-')

# %%
#Creating DataFrame
Pune=pd.DataFrame({'Brand':Brand5[:360], 'Model':Model5[:360], 'Variant':Variant5[:360], 'Manufacturing_Year':Manufacturing_Year5[:360], 'Driven_KiloMeters':Driven_KiloMeters5[:360], 'Fuel':Fuel5[:360], 'Location':Location5[:360], 'Car_Price':Car_Price5[:360]})
Pune
# Out:
# Empty DataFrame
# Columns: [Brand, Model, Variant, Manufacturing_Year, Driven_KiloMeters, Fuel, Location, Car_Price]
# Index: []

# %%
driver5.close()

# %% [markdown]
# ## Jaipur

# %%
driver6=webdriver.Chrome(r"C:\Users\hp pc\Downloads\chromedriver_win32 (1)\chromedriver.exe")
url6=("https://www.cardekho.com/used-cars")
driver6.get(url6)
driver6.maximize_window()
time.sleep(2)

# %%
location_Jaipur= driver6.find_element(By.XPATH,"//a[@title='Used cars in Jaipur']").click()

# %%
# scrolling the web page to get more images
for _ in range(500):
    driver6.execute_script("window.scrollBy(0,1000)")

# %%
urls6 = []
for i in range(30):
    for j in driver6.find_elements(By.XPATH,'//div[@class="gsc_col-xs-7  carsName"]/a'):
        
        urls6.append(j.get_attribute('href'))

time.sleep(2)

print(len(urls6))
# Out:
# 1120

# %%
#Creating empty list 
Brand6= []
Model6 = []
Variant6=[]
Manufacturing_Year6 = []
Driven_KiloMeters6= []
Fuel6 = []
Location6= []
Car_Price6= []


#Fetching data for Brand    
try:
    Brand_name6=driver6.find_elements(By.XPATH,"//div[@class='gsc_col-xs-7  carsName']/a")
    for i in Brand_name6:
        Brand6.append(i.text.split(" ")[1])
except NoSuchElementException as e:
    Brand6.append('-')
    
#Fetching data for Model   
try:
    Model_name6=driver6.find_elements(By.XPATH,"//div[@class='gsc_col-xs-7  carsName']/a")
    for i in Model_name6:
        Model6.append(i.text[5:])
except NoSuchElementException as e:
    Model6.append('-')

#Fetching data for Variant   
try:
    Variant_name6=driver6.find_elements(By.XPATH,"//div[@class='car_variant']")
    for i in Variant_name6:
        Variant6.append(i.text)
except NoSuchElementException as e:
    Variant6.append('-')
    
#Fetching data for Manufacturing    
try:
    Manufacturing6=driver6.find_elements(By.XPATH,"//div[@class='gsc_col-xs-7  carsName']/a")
    for i in Manufacturing6:
        Manufacturing_Year6.append(i.text.split(" ")[0])
except NoSuchElementException as e:
    Manufacturing_Year6.append('-') 
    
#Fetching data for Driven_KiloMeters    
try:
    Driven_KiloMeter6=driver6.find_elements(By.XPATH,'//div[@class="truncate dotlist-2"]/div[1]')
    for i in Driven_KiloMeter6:
        Driven_KiloMeters6.append(i.text)
except NoSuchElementException as e:
    Driven_KiloMeters6.append('-')    

#Fetching data for Fuel    
try:
    Fuel_name6=driver6.find_elements(By.XPATH,'//div[@class="truncate dotlist-2"]/div[2]')
    for i in Fuel_name6:
        Fuel6.append(i.text)
except NoSuchElementException as e:
    Fuel6.append('-')
    
#Fetching data for Car_Price    
try:
    Car_Pr6=driver6.find_elements(By.XPATH,"//span[@class='amnt ']")
    for i in Car_Pr6:
        Car_Price6.append(i.text)
except NoSuchElementException as e:
    Car_Price6.append('-')

# %%
print(len(Brand6),len(Model6),len(Variant6),len(Manufacturing_Year6), len(Driven_KiloMeters6), len(Fuel6), len(Car_Price6))
# Out:
# 40 40 40 40 40 40 40

# %%
#Fetching data for Location       
try:
    Location_name6=driver6.find_elements(By.XPATH,'//div[@class="gsc_col-xs-12 mainheading"]')
    for j in range (200):
        for i in Location_name6:
            Location6.append(i.text[13:])
except NoSuchElementException as e:
    Location6.append('-')

# %%
#Creating DataFrame
Jaipur=pd.DataFrame({'Brand':Brand6[:200], 'Model':Model6[:200], 'Variant':Variant6[:200], 'Manufacturing_Year':Manufacturing_Year6[:200], 'Driven_KiloMeters':Driven_KiloMeters6[:200], 'Fuel':Fuel6[:200],  'Car_Price':Car_Price6[:200]})
Jaipur
# Out:
#             Brand                   Model                Variant  \
# 0         Renault            Renault KWID                    RXL
# 1           Honda              Honda City          i-VTEC CVT ZX
# 2         Hyundai           Hyundai Venue      SX Plus Turbo DCT
# 3           Honda             Honda Amaze      V CVT Petrol BSIV
# 4           Honda              Honda City                 ZX CVT
# 5          Nissan            Nissan Kicks           1.3 Turbo XV
# 6          Maruti             Maruti Ciaz             Alpha BSIV
# 7         Renault          Renault Duster              RXZ Turbo
# 8          Maruti         Maruti Alto 800                    VXI
# 9           Honda              Honda City          i VTEC CVT VX
# 10          Honda              Honda City                 ZX CVT
# 11        Hyundai         Hyundai Alcazar              Signature
# 12        Hyundai             Hyundai i20     Petrol Asta Option
# ...

# %%
car_dekho=pd.concat([Ahmedabad,Bangalore,Delhi,Mumbai,Pune,Jaipur], ignore_index=True)
car_dekho
# Out:
#             Brand                   Model  \
# 0          Maruti           Maruti Baleno
# 1          Maruti             Maruti Ciaz
# 2         Hyundai           Hyundai Venue
# 3          Maruti          Maruti Celerio
# 4          Maruti           Maruti Baleno
# 5         Hyundai           Hyundai Creta
# 6          Maruti             Maruti Ciaz
# 7          Maruti           Maruti Baleno
# 8         Hyundai             Hyundai i20
# 9          Toyota       Toyota Etios Liva
# 10       Mahindra           Mahindra Thar
# 11         Maruti             Maruti Ciaz
# 12       Mahindra         Mahindra XUV500
# 13        Renault            Renault KWID
# 14        Hyundai             Hyundai i20
# 15        Hyundai             Hyundai i20
# 16            BMW                  BMW X5
# 17        Hyundai             Hyundai i20
# 18            BMW            BMW 5 Series
# 19            BMW                  BMW X1
# 20        Renault            Renault KWID
# ...

# %%
car_dekho.to_csv('car_dekho', index=True)

# %%
driver6.close()

# %% [markdown]
# ## 2. Scraping data from "OLX" Website

# %%
driver7=webdriver.Chrome(r"C:\Users\hp pc\Downloads\chromedriver_win32 (1)\chromedriver.exe")
url7=("https://www.olx.in/cars_c84")
driver7.get(url7)
driver7.maximize_window()
time.sleep(2)

# %%
# scrolling the web page 
for b in range(20):
    driver7.execute_script("window.scrollBy(0,1000)")

button=driver7.find_elements(By.XPATH,'//li[@class="_3OF2S"]/div')

# %%
urls7 = []
for i in range(150):
    for j in driver7.find_elements(By.XPATH,'//li[@class="_31j8e"]/a'):
        urls7.append(j.get_attribute('href'))

print(len(urls7))
# Out:
# 0

# %%
Location8= []
for _ in range(100):
    driver7.execute_script("window.scrollBy(0,1000)")
#Fetching data for Location   
    try:
        Location_name7=driver7.find_elements(By.XPATH,"//div[@class='_1zvfB']")
        for i in Location_name7:
            Location8.append(i.text.split("\n")[0])
    except NoSuchElementException as e:
        Location8.append('-')

# %%
len(Location8)
# Out:
# 0

# %%
#Creating empty list 

Brand7 = []
Model7 = []
Variant7=[]
Manufacturing_Year7 = []
Driven_KiloMeters7= []
Fuel7 = []
Car_Price7= []

for i in urls7[:2000]:
    driver7.get(i)
    time.sleep(1)   
    
    try:

        #Fetching data for Brand    
        try:
            Brand_name7=driver7.find_elements(By.XPATH,"//div[@class='_35xN1']")
            for i in Brand_name7:
                Brand7.append(i.text.split(' ')[0])
        except NoSuchElementException as e:
            Brand7.append('-')


        #Fetching data for Model   
        try:
            Model_name7=driver7.find_elements(By.XPATH,"//div[@class='_35xN1']")
            for i in Model_name7:
                Model7.append(i.text.split("(")[0])
        except NoSuchElementException as e:
            Model7.append('-')

        #Fetching data for Variant   
        try:
            Variant_name7=driver7.find_elements(By.XPATH,"//div[@class='_3tLee']")
            for i in Variant_name7:
                Variant7.append(i.text)
        except NoSuchElementException as e:
            Variant7.append('-')

        #Fetching data for Manufacturing    
        try:
            Manufacturing7=driver7.find_elements(By.XPATH,"//div[@class='_35xN1']")
            for i in Manufacturing7:
                Manufacturing_Year7.append(i.text.split("(")[1].replace(")", " "))
        except NoSuchElementException as e:
            Manufacturing_Year7.append('-')    

        #Fetching data for Driven_KiloMeters    
        try:
            Driven_KiloMeter7=driver7.find_elements(By.XPATH,'//div[@class="aOxkz"]/div[2]/div')
            for i in Driven_KiloMeter7:
                Driven_KiloMeters7.append(i.text)
        except NoSuchElementException as e:
            Driven_KiloMeters7.append('-')    

        #Fetching data for Fuel    
        try:
            Fuel_name7=driver7.find_elements(By.XPATH,'//div[@class="aOxkz"]/div[1]/div')
            for i in Fuel_name7:
                Fuel7.append(i.text)
        except NoSuchElementException as e:
            Fuel7.append('-')

        #Fetching data for Car_Price    
        try:
            Car_Pr7=driver7.find_elements(By.XPATH,"//div[@class='_3FkyT']")
            for i in Car_Pr7:
                Car_Price7.append(i.text)
        except NoSuchElementException as e:
            Car_Price7.append('-')
    except TimeoutException:
        pass        
    except NoSuchElementException:
        pass

# %%
print(len(Brand7),len(Model7),len(Variant7),len(Manufacturing_Year7), len(Driven_KiloMeters7), len(Fuel7), len(Car_Price7))
# Out:
# 0 0 0 0 0 0 0

# %%
Olx_Car1 = pd.DataFrame({'Brand':Brand7[:1970], 'Model':Model7[:1970], 'Variant':Variant7[:1970], 'Manufacturing_Year':Manufacturing_Year7[:1970], 'Driven_KiloMeters':Driven_KiloMeters7[:1970], 'Fuel':Fuel7[:1970],  'Location':Location8[:1970], 'Car_Price':Car_Price7[:1970]})
Olx_Car1
# Out:
# Empty DataFrame
# Columns: [Brand, Model, Variant, Manufacturing_Year, Driven_KiloMeters, Fuel, Location, Car_Price]
# Index: []

# %%
#Creating empty list 
Brand8 = []
Model8 = []
Variant8=[]
Manufacturing_Year8 = []
Driven_KiloMeters8= []
Fuel8 = []
Car_Price8= []

for i in urls7[2000:2500]:
    driver7.get(i)
    time.sleep(1)   
    
    try:

        #Fetching data for Brand    
        try:
            Brand_name8=driver7.find_elements(By.XPATH,"//div[@class='_35xN1']")
            for i in Brand_name8:
                Brand8.append(i.text.split(' ')[0])
        except NoSuchElementException as e:
            Brand8.append('-')


        #Fetching data for Model   
        try:
            Model_name8=driver7.find_elements(By.XPATH,"//div[@class='_35xN1']")
            for i in Model_name8:
                Model8.append(i.text.split("(")[0])
        except NoSuchElementException as e:
            Model8.append('-')

        #Fetching data for Variant   
        try:
            Variant_name8=driver7.find_elements(By.XPATH,"//div[@class='_3tLee']")
            for i in Variant_name8:
                Variant8.append(i.text)
        except NoSuchElementException as e:
            Variant8.append('-')

        #Fetching data for Manufacturing    
        try:
            Manufacturing8=driver7.find_elements(By.XPATH,"//div[@class='_35xN1']")
            for i in Manufacturing8:
                Manufacturing_Year8.append(i.text.split("(")[1].replace(")", " "))
        except NoSuchElementException as e:
            Manufacturing_Year8.append('-')    

        #Fetching data for Driven_KiloMeters    
        try:
            Driven_KiloMeter8=driver7.find_elements(By.XPATH,'//div[@class="aOxkz"]/div[2]/div')
            for i in Driven_KiloMeter8:
                Driven_KiloMeters8.append(i.text)
        except NoSuchElementException as e:
            Driven_KiloMeters8.append('-')    

        #Fetching data for Fuel    
        try:
            Fuel_name8=driver7.find_elements(By.XPATH,'//div[@class="aOxkz"]/div[1]/div')
            for i in Fuel_name8:
                Fuel8.append(i.text)
        except NoSuchElementException as e:
            Fuel8.append('-')

        #Fetching data for Car_Price    
        try:
            Car_Pr8=driver7.find_elements(By.XPATH,"//div[@class='_3FkyT']")
            for i in Car_Pr8:
                Car_Price8.append(i.text)
        except NoSuchElementException as e:
            Car_Price8.append('-')
    except TimeoutException:
        pass        
    except NoSuchElementException:
        pass

# %%
print(len(Brand8),len(Model8),len(Variant8),len(Manufacturing_Year8), len(Driven_KiloMeters8), len(Fuel8), len(Car_Price8))
# Out:
# 0 0 0 0 0 0 0

# %%
Olx_Car2 = pd.DataFrame({'Brand':Brand8[:493], 'Model':Model8[:493], 'Variant':Variant8[:493], 'Manufacturing_Year':Manufacturing_Year8[:493], 'Driven_KiloMeters':Driven_KiloMeters8[:493], 'Fuel':Fuel8[:493],  'Location':Location8[1970:2463], 'Car_Price':Car_Price8[:493]})
Olx_Car2
# Out:
# Empty DataFrame
# Columns: [Brand, Model, Variant, Manufacturing_Year, Driven_KiloMeters, Fuel, Location, Car_Price]
# Index: []

# %%
Olx_Car=pd.concat([Olx_Car1, Olx_Car2], ignore_index=True)
Olx_Car
# Out:
# Empty DataFrame
# Columns: [Brand, Model, Variant, Manufacturing_Year, Driven_KiloMeters, Fuel, Location, Car_Price]
# Index: []

# %%
Olx_Car.to_csv('Olx_Car', index=True)

# %%
driver7.close()

# %% [markdown]
# ## 3. Scraping data from "cars24" Website

# %% [markdown]
# ### Delhi

# %%
driver9=webdriver.Chrome(r"C:\Users\hp pc\Downloads\chromedriver_win32 (1)\chromedriver.exe")
url9=("https://www.cars24.com/buy-used-cars/")
driver9.get(url9)
driver9.maximize_window()
time.sleep(2)

# %%
# scrolling the web page 
for _ in range(100):
    driver9.execute_script("window.scrollBy(0,1000)")

# %%
location1= driver9.find_element(By.XPATH,'//li[@data-title="New Delhi"]')

# %%
# scrolling the web page 
for _ in range(100):
    driver9.execute_script("window.scrollBy(0,1000)")

# %%
#Creating empty list 
Brand9 = []
Model9 = []
Variant9=[]
Manufacturing_Year9 = []
Driven_KiloMeters9= []
Fuel9 = []
Number_of_Owners9 = []
Location9= []
Car_Price9= []

#Fetching data for Brand    
try:
    Brand_name9=driver9.find_elements(By.XPATH,"//h2[@class='_3FpCg']")
    for i in Brand_name9:
        Brand9.append(i.text)
except NoSuchElementException as e:
    Brand9.append('-')


#Fetching data for Model   
try:
    Model_name9=driver9.find_elements(By.XPATH,"//h2[@class='_3FpCg']")
    for i in Model_name9:
        Model9.append(i.text)
except NoSuchElementException as e:
    Model9.append('-')

#Fetching data for Variant   
try:
    Variant_name9=driver9.find_elements(By.XPATH,"//p[@class='cvakB']")
    for i in Variant_name9:
        Variant9.append(i.text)
except NoSuchElementException as e:
    Variant9.append('-')

#Fetching data for Manufacturing    
try:
    Manufacturing9=driver9.find_elements(By.XPATH,"//h2[@class='_3FpCg']")
    for i in Manufacturing9:
        Manufacturing_Year9.append(i.text.split(" ")[0])
except NoSuchElementException as e:
    Manufacturing_Year9.append('-')    

#Fetching data for Driven_KiloMeters    
try:
    Driven_KiloMeter9=driver9.find_elements(By.XPATH,'//ul[@class="bVR0c"]/li[1]')
    for i in Driven_KiloMeter9:
        Driven_KiloMeters9.append(i.text)
except NoSuchElementException as e:
    Driven_KiloMeters9.append('-')    

#Fetching data for Fuel    
try:
    Fuel_name9=driver9.find_elements(By.XPATH,'//ul[@class="bVR0c"]/li[3]')
    for i in Fuel_name9:
        Fuel9.append(i.text)
except NoSuchElementException as e:
    Fuel9.append('-')

#Fetching data for Number_of_Owners    
try:
    Number_of_Owner9=driver9.find_elements(By.XPATH,'//ul[@class="bVR0c"]/li[2]')
    for i in Number_of_Owner9:
        Number_of_Owners9.append(i.text)
except NoSuchElementException as e:
    Number_of_Owners9.append('-')


#Fetching data for Car_Price    
try:
    Car_Pr9=driver9.find_elements(By.XPATH,"//div[@class='_7udZZ']/span[1]")
    for i in Car_Pr9:
        Car_Price9.append(i.text)
except NoSuchElementException as e:
    Car_Price9.append('-')

# %%
print(len(Brand9),len(Model9),len(Variant9),len(Manufacturing_Year9), len(Driven_KiloMeters9), len(Fuel9), len(Number_of_Owners9),  len(Car_Price9))
# Out:
# 5 5 5 5 5 5 5 5

# %%
#Fetching data for Location   
for i in range (664):
    Location9.append("Delhi")

# %%
car24= pd.DataFrame({'Brand':Brand9, 'Model':Model9, 'Variant':Variant9, 'Manufacturing_Year':Manufacturing_Year9, 'Driven_KiloMeters':Driven_KiloMeters9, 'Fuel':Fuel9, 'Number_of_Owners':Number_of_Owners9,  'Car_Price':Car_Price9})
car24
# Out:
#                Brand              Model     Variant Manufacturing_Year  \
# 0  2021 Maruti Swift  2021 Maruti Swift  LXI Manual               2021
# 1  2019 Maruti Swift  2019 Maruti Swift  LXI Manual               2019
# 2  2019 Maruti Swift  2019 Maruti Swift  VXI Manual               2019
# 3
# 4
#
#   Driven_KiloMeters    Fuel Number_of_Owners  Car_Price
# 0          5,234 km  Petrol        1st Owner  ₹6,02,399
# 1         12,046 km  Petrol        2nd Owner  ₹5,34,799
# 2         24,028 km  Petrol        1st Owner  ₹5,99,399
# 3
# 4

# %% [markdown]
# ### Mumbai

# %%
driver_9=webdriver.Chrome(r"C:\Users\hp pc\Downloads\chromedriver_win32 (1)\chromedriver.exe")
url_9=("https://www.cars24.com/buy-used-cars/")
driver_9.get(url_9)
driver_9.maximize_window()
time.sleep(2)

# %%
# scrolling the web page 
for _ in range(20):
    driver_9.execute_script("window.scrollBy(0,1000)")

# %%
location2= driver_9.find_elements(By.XPATH,'//li[@data-title="Mumbai"]')

# %%
# scrolling the web page 
for _ in range(100):
    driver_9.execute_script("window.scrollBy(0,1000)")

# %%
#Creating empty list 
Brand_9 = []
Model_9 = []
Variant_9=[]
Manufacturing_Yr_9 = []
Driven_KMs_9= []
Fuel_9 = []
Number_of_Owners_9 = []
Location_9= []
Car_Price_9= []

#Fetching data for Brand    
try:
    Brand_name_9=driver_9.find_elements(By.XPATH,"//h2[@class='_3FpCg']")
    for i in Brand_name_9:
        Brand_9.append(i.text)
except NoSuchElementException as e:
    Brand_9.append('-')


#Fetching data for Model   
try:
    Model_name_9=driver_9.find_elements(By.XPATH,"//h2[@class='_3FpCg']")
    for i in Model_name_9:
        Model_9.append(i.text)
except NoSuchElementException as e:
    Model_9.append('-')

#Fetching data for Variant   
try:
    Variant_name_9=driver_9.find_elements(By.XPATH,"//p[@class='cvakB']")
    for i in Variant_name_9:
        Variant_9.append(i.text)
except NoSuchElementException as e:
    Variant_9.append('-')

#Fetching data for Manufacturing    
try:
    Manufacturing_9=driver_9.find_elements(By.XPATH,"//h2[@class='_3FpCg']")
    for i in Manufacturing_9:
        Manufacturing_Yr_9.append(i.text.split(" ")[0])
except NoSuchElementException as e:
    Manufacturing_Yr_9.append('-')    

#Fetching data for Driven_KiloMeters    
try:
    Driven_KiloMeter_9=driver_9.find_elements(By.XPATH,'//ul[@class="bVR0c"]/li[1]')
    for i in Driven_KiloMeter_9:
        Driven_KMs_9.append(i.text)
except NoSuchElementException as e:
    Driven_KMs_9.append('-')    

#Fetching data for Fuel    
try:
    Fuel_name_9=driver_9.find_elements(By.XPATH,'//ul[@class="bVR0c"]/li[3]')
    for i in Fuel_name_9:
        Fuel_9.append(i.text)
except NoSuchElementException as e:
    Fuel_9.append('-')

#Fetching data for Number_of_Owners    
try:
    Number_of_Owner_9=driver_9.find_elements(By.XPATH,'//ul[@class="bVR0c"]/li[2]')
    for i in Number_of_Owner_9:
        Number_of_Owners_9.append(i.text)
except NoSuchElementException as e:
    Number_of_Owners_9.append('-')


#Fetching data for Car_Price    
try:
    Car_Pr_9=driver_9.find_elements(By.XPATH,"//div[@class='_7udZZ']/span[1]")
    for i in Car_Pr_9:
        Car_Price_9.append(i.text)
except NoSuchElementException as e:
    Car_Price_9.append('-')

# %%
print(len(Brand_9),len(Model_9),len(Variant_9),len(Manufacturing_Yr_9), len(Driven_KMs_9), len(Fuel_9), len(Number_of_Owners_9),  len(Car_Price_9))
# Out:
# 5 5 5 5 5 5 5 5

# %%
#Fetching data for Location   
for i in range (465):
    Location_9.append("Delhi")

# %%
car_24= pd.DataFrame({'Brand':Brand_9, 'Model':Model_9, 'Variant':Variant_9, 'Manufacturing_Year':Manufacturing_Yr_9, 'Driven_KiloMeters':Driven_KMs_9, 'Fuel':Fuel_9, 'Number_of_Owners':Number_of_Owners_9,  'Car_Price':Car_Price_9})
car_24
# Out:
#                   Brand                 Model     Variant Manufacturing_Year  \
# 0  2013 Maruti Alto 800  2013 Maruti Alto 800  LXI Manual               2013
# 1     2021 Maruti Swift     2021 Maruti Swift  LXI Manual               2021
# 2     2021 Maruti Swift     2021 Maruti Swift  LXI Manual               2021
# 3
# 4
#
#   Driven_KiloMeters    Fuel Number_of_Owners  Car_Price
# 0         15,999 km  Petrol        1st Owner  ₹2,74,599
# 1          4,741 km  Petrol        1st Owner  ₹6,08,999
# 2          5,234 km  Petrol        1st Owner  ₹6,02,399
# 3
# 4

# %%
driver_9.close()

# %% [markdown]
# ### Bengaluru

# %%
driver0=webdriver.Chrome(r"C:\Users\hp pc\Downloads\chromedriver_win32 (1)\chromedriver.exe")
url0=("https://www.cars24.com/buy-used-cars/")
driver0.get(url0)
driver0.maximize_window()
time.sleep(2)

# %%
# scrolling the web page 
for _ in range(10):
    driver0.execute_script("window.scrollBy(0,1000)")

# %%
location3= driver0.find_elements(By.XPATH,'//li[@data-title="Bengaluru"]')

# %%
# scrolling the web page 
for _ in range(100):
    driver0.execute_script("window.scrollBy(0,1000)")

# %%
#Creating empty list 
Brand0 = []
Model0 = []
Variant0=[]
Manufacturing_Year0 = []
Driven_KiloMeters0= []
Fuel0 = []
Number_of_Owners0 = []
Location0= []
Car_Price0= []

#Fetching data for Brand    
try:
    Brand_name0=driver0.find_elements(By.XPATH,"//h2[@class='_3FpCg']")
    for i in Brand_name0:
        Brand0.append(i.text)
except NoSuchElementException as e:
    Brand0.append('-')


#Fetching data for Model   
try:
    Model_name0=driver0.find_elements(By.XPATH,"//h2[@class='_3FpCg']")
    for i in Model_name0:
        Model0.append(i.text)
except NoSuchElementException as e:
    Model0.append('-')

#Fetching data for Variant   
try:
    Variant_name0=driver0.find_elements(By.XPATH,"//p[@class='cvakB']")
    for i in Variant_name0:
        Variant0.append(i.text)
except NoSuchElementException as e:
    Variant0.append('-')

#Fetching data for Manufacturing    
try:
    Manufacturing0=driver0.find_elements(By.XPATH,"//h2[@class='_3FpCg']")
    for i in Manufacturing0:
        Manufacturing_Year0.append(i.text.split(" ")[0])
except NoSuchElementException as e:
    Manufacturing_Year0.append('-')    

#Fetching data for Driven_KiloMeters    
try:
    Driven_KiloMeter0=driver0.find_elements(By.XPATH,'//ul[@class="bVR0c"]/li[1]')
    for i in Driven_KiloMeter0:
        Driven_KiloMeters0.append(i.text)
except NoSuchElementException as e:
    Driven_KiloMeters0.append('-')    

#Fetching data for Fuel    
try:
    Fuel_name0=driver0.find_elements(By.XPATH,'//ul[@class="bVR0c"]/li[3]')
    for i in Fuel_name0:
        Fuel0.append(i.text)
except NoSuchElementException as e:
    Fuel0.append('-')

#Fetching data for Number_of_Owners    
try:
    Number_of_Owner0=driver0.find_elements(By.XPATH,'//ul[@class="bVR0c"]/li[2]')
    for i in Number_of_Owner0:
        Number_of_Owners0.append(i.text)
except NoSuchElementException as e:
    Number_of_Owners0.append('-')


#Fetching data for Car_Price    
try:
    Car_Pr0=driver0.find_elements(By.XPATH,"//div[@class='_7udZZ']/span[1]")
    for i in Car_Pr0:
        Car_Price0.append(i.text)
except NoSuchElementException as e:
    Car_Price0.append('-')

# %%
print(len(Brand0),len(Model0),len(Variant0),len(Manufacturing_Year0), len(Driven_KiloMeters0), len(Fuel0), len(Number_of_Owners0),  len(Car_Price0))
# Out:
# 5 5 5 5 5 5 5 5

# %%
#Fetching data for Location   
for i in range (624):
    Location0.append("Delhi")

# %%
car24_= pd.DataFrame({'Brand':Brand0, 'Model':Model0, 'Variant':Variant0, 'Manufacturing_Year':Manufacturing_Year0, 'Driven_KiloMeters':Driven_KiloMeters0, 'Fuel':Fuel0, 'Number_of_Owners':Number_of_Owners0,  'Car_Price':Car_Price0})
car24_
# Out:
#                Brand              Model     Variant Manufacturing_Year  \
# 0  2021 Maruti Swift  2021 Maruti Swift  LXI Manual               2021
# 1  2019 Maruti Swift  2019 Maruti Swift  LXI Manual               2019
# 2  2019 Maruti Swift  2019 Maruti Swift  VXI Manual               2019
# 3
# 4
#
#   Driven_KiloMeters    Fuel Number_of_Owners  Car_Price
# 0          5,234 km  Petrol        1st Owner  ₹6,02,399
# 1         12,046 km  Petrol        2nd Owner  ₹5,34,799
# 2         24,028 km  Petrol        1st Owner  ₹5,99,399
# 3
# 4

# %%
driver0.close()

# %%
cars24=pd.concat([car24,car_24, car24_], ignore_index=True)
cars24
# Out:
#                    Brand                 Model     Variant Manufacturing_Year  \
# 0      2021 Maruti Swift     2021 Maruti Swift  LXI Manual               2021
# 1      2019 Maruti Swift     2019 Maruti Swift  LXI Manual               2019
# 2      2019 Maruti Swift     2019 Maruti Swift  VXI Manual               2019
# 3
# 4
# 5   2013 Maruti Alto 800  2013 Maruti Alto 800  LXI Manual               2013
# 6      2021 Maruti Swift     2021 Maruti Swift  LXI Manual               2021
# 7      2021 Maruti Swift     2021 Maruti Swift  LXI Manual               2021
# 8
# 9
# 10     2021 Maruti Swift     2021 Maruti Swift  LXI Manual               2021
# 11     2019 Maruti Swift     2019 Maruti Swift  LXI Manual               2019
# 12     2019 Maruti Swift     2019 Maruti Swift  VXI Manual               2019
# 13
# 14
#
#    Driven_KiloMeters    Fuel Number_of_Owners  Car_Price
# 0           5,234 km  Petrol        1st Owner  ₹6,02,399
# ...

# %% [markdown]
# ## Merging DataFrame of both website

# %%
car_price=pd.concat([car_dekho,Olx_Car,cars24], ignore_index=True)

# %%
car_price
# Out:
#                 Brand              Model                 Variant  \
# 0              Maruti      Maruti Baleno               1.2 Delta
# 1              Maruti        Maruti Ciaz              Delta BSIV
# 2             Hyundai      Hyundai Venue  SX Plus Turbo DCT BSIV
# 3              Maruti     Maruti Celerio   VXI CNG Optional BSIV
# 4              Maruti      Maruti Baleno               1.2 Delta
# ..                ...                ...                     ...
# 70  2021 Maruti Swift  2021 Maruti Swift              LXI Manual
# 71  2019 Maruti Swift  2019 Maruti Swift              LXI Manual
# 72  2019 Maruti Swift  2019 Maruti Swift              VXI Manual
# 73
# 74
#
#    Manufacturing_Year Driven_KiloMeters    Fuel  Location   Car_Price  \
# 0                2017        61,628 kms  Petrol       NaN   5.65 Lakh
# 1                2019        34,474 kms  Petrol       NaN   8.17 Lakh
# 2                2019        26,684 kms  Petrol       NaN  10.53 Lakh
# ...

# %% [markdown]
# ### Converting data into CSV

# %%
car_price.to_csv('car_price.csv', index=True)
